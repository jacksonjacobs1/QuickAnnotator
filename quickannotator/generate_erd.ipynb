# %%
from quickannotator.db import Base, get_session, init_db

# %%
init_db()
# Out:
# InitSpatiaMetaData() error:"table spatial_ref_sys already exists"

# %%
Base.metadata.tables
# Out:
# FacadeDict({'project': Table('project', MetaData(), Column('id', Integer(), table=<project>, primary_key=True, nullable=False), Column('name', Text(), table=<project>, nullable=False), Column('description', Text(), table=<project>, default=ScalarElementColumnDefault('')), Column('is_dataset_large', Boolean(), table=<project>, default=ScalarElementColumnDefault(False)), Column('datetime', DateTime(), table=<project>, default=CallableColumnDefault(<function datetime.now at 0x7c13182ca320>)), schema=None), 'image': Table('image', MetaData(), Column('id', Integer(), table=, primary_key=True, nullable=False), Column('project_id', Integer(), ForeignKey('project.id'), table=, nullable=False), Column('name', Text(), table=, nullable=False), Column('path', Text(), table=), Column('base_height', Integer(), table=), Column('base_width', Integer(), table=), Column('dz_tilesize', Integer(), table=), Column('embedding_coord', Geometry(geometry_type='POINT', from_text='ST_GeomFromEWKT', name='geome
# ...

# %%
from eralchemy2 import render_er

# Draw from SQLAlchemy base
render_er(Base.metadata, 'erd_from_sqlalchemy.png')
